# %% [markdown]
# <a href="https://colab.research.google.com/github/Najmudino/KKA-X-Semester-1/blob/main/1_Fungsi_print_M_Najmudino_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Menampilkan Teks Bebas

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Muhammad Najmudino")
# Out:
# Muhammad Najmudino

# %% [markdown]
# #2. Menampilkan Nilai Variabel

# %%
beratbadan = 50
print(beratbadan)
# Out:
# 50

# %%
tinggibadan = 160
print(tinggibadan)
# Out:
# 160

# %%
Nama = "Muhammad Najmudino"
print(Nama)
# Out:
# Muhammad Najmudino

# %%
namaidola = "orang tua"
print(namaidola)
# Out:
# orang tua

# %% [markdown]
#    3. Menampilkan Teks Bebas dan Nilai Variabel

# %%
print("Halo nama saya ", Nama,". Berat badan saya",beratbadan,"Kg")
# Out:
# Halo nama saya  Muhammad Najmudino . Berat badan saya 50 Kg

# %%
print("Halo nama saya "+ Nama+". Berat badan saya "+str(beratbadan)+" Kg.")
# Out:
# Halo nama saya Muhammad Najmudino. Berat badan saya 50 Kg.

# %%
print(f"Halo nama saya {Nama}. Berat badan saya {beratbadan} Kg.")
# Out:
# Halo nama saya Muhammad Najmudino. Berat badan saya 50 Kg.

# %% [markdown]
#  4. Escape Character

# %%
print("Nama: M. najmudino")
print("Kelas: X-5")
print("No absen: 55")
# Out:
# Nama: M. najmudino
# Kelas: X-5
# No absen: 55

# %%
print("Nama: M. najmudino\nKelas: X-5\nNo absen: 55")
# Out:
# Nama: M. najmudino
# Kelas: X-5
# No absen: 55

# %%
print("""Nama\t\t: M. najmudi
noKelas\t\t: X-5
No. absen\t: 55""")
# Out:
# Nama		: M. najmudi
# noKelas		: X-5
# No. absen	: 55

# %%
print('Nama saya ja\'far shodiq')
# Out:
# Nama saya ja'far shodiq

# %%
print("Nama saya Ja'far shodiq")
# Out:
# Nama saya Ja'far shodiq

# %%
print("Nama saya Ja'far shodiq")
# Out:
# Nama saya Ja'far shodiq

# %%
print('Bu shinta berkata,"Tolong perhatikan TV dan saya."'  )
# Out:
# Bu shinta berkata,"Tolong perhatikan TV dan saya."

# %%
print("Bu shinta berkata,\"Tolong perhatikan TV dan saya.\"")
# Out:
# Bu shinta berkata,"Tolong perhatikan TV dan saya."

# %%
print("Lokasi file tugas KKA adalah di Local disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah di Local disk C:\KKA\Tugas

# %%
print("Bu Shinta rberkata,\"Berikut adalah daftar piket harian kelas X.5\nyang disimpan di file D:\\MAN Demak\\Jadwal Piket.\"\n\nSenin\tSelasa\tRabu\nJielo\tHasbi\tNaufal\nAzam\tAida\tA'inun")
# Out:
# Bu Shinta rberkata,"Berikut adalah daftar piket harian kelas X.5
# yang disimpan di file D:\MAN Demak\Jadwal Piket."
#
# Senin	Selasa	Rabu
# Jielo	Hasbi	Naufal
# Azam	Aida	A'inun

# %% [markdown]
# 
#  4. Paramater Fungsi print

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"

print(nama_siswa_1, end="-")
print(nama_siswa_2, end="-")
print(nama_siswa_3)
# Out:
# Jielo-Aida-Dani

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_4, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_1, end="/")
print(nama_siswa_3)
# Out:
# Nurul/Aida/Jielo/Dani

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_5, nama_siswa_6, sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_5, nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_8, sep="*")
print(nama_siswa_7, nama_siswa_6, nama_siswa_5, nama_siswa_7, nama_siswa_7, sep="-")
# Out:
# Hasbi*Naufal*Rendra*Habibi*Naufal
# Rendra-Habibi-Hasbi-Rendra-Rendra
